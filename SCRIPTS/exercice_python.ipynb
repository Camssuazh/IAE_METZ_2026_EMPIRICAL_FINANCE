# %% [markdown]
# # Premiers exercices

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Analyse Bourse")
# Out:
# Analyse Bourse

# %% [markdown]
# # Let's go learning PYTHON

# %%
# Ceci est un commentaire dans la cellule de code
# Python est une programmation orientée OBJET. On déf des varaibles

name = "Camille"
print(name)
# Out:
# Camille

# %%
# Pour les chiffres on a
age = 26 #INTEGRER

# %%
# un dictionnaire c'est CLE VALEUR

prices = {"APPL":248.04,
          "GOOGLE":328.33,
          "TSLA":437.43}

# %%
prices
# Out:
# {'APPL': 248.04, 'GOOGLE': 328.33, 'TSLA': 437.43}

# %%
# Comment avoir les données boursières ?
# En effet on ne va pas recopier à la main des dictionnaires.

# %%
# DONC ON UTILISE LES PACKAGES
! pip install yfinance
# YAHOO FINANCE
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
! pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ticker = "AAPL"

# %%
# Pour prendre les données du package on utilise une fonction
# qui est def dans ce package pour extraire la donnée

data = yf.download(ticker, start="2020-01-01",progress=False)

# %%
data
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.468254   72.528574   71.223252   71.476592  135480400
# 2020-01-03   71.763725   72.523754   71.539337   71.696167  146322800
# 2020-01-06   72.335564   72.374169   70.634547   70.885479  118387200
# 2020-01-07   71.995354   72.600960   71.775789   72.345204  108872000
# 2020-01-08   73.153481   73.455080   71.698566   71.698566  132079200
# ...                ...         ...         ...         ...        ...
# 2026-01-26  255.410004  256.559998  249.800003  251.479996   55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013   49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994   41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000   67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998   92352600
#
# [1528 rows x 5 columns]

# %%
data.head() # les 5 premières
data.tail() # les 5 dernières
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-01-26  255.410004  256.559998  249.800003  251.479996  55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013  49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994  41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000  67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998  92352600

# %%
data = yf.download(ticker, start="2020-01-01", auto_adjust=False)
# On utilise le 'Adj Close'
data['Returns'] = data['Adj Close'].pct_change()

# Il y a environ 252 jours de trading par an
mean_return_daily = data['Returns'].mean()
volatility_daily = data['Returns'].std()

annualized_return = mean_return_daily = 252
annualized_volatility = volatility_daily * np.sqrt(252)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
sharpe_ratio = annualized_return / volatility_daily

print(f"--- Analyze pour {ticker} ---")
print(f"Rendement Annualisé : {annualized_return:.2%}")
print(f"Volatilité Annualisée : {annualized_volatility:.2%}")
# Out:
# --- Analyze pour AAPL ---
# Rendement Annualisé : 25200.00%
# Volatilité Annualisée : 31.69%

# %%
plt.figure(figsize=(10,6))
plt.plot(data['Close'], label = 'AAPL Closing Price')
plt.title('AAPL Stock Price Over Time')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# # La structure d'un projet python :
# Une cellule ou l'on importe TOUS LES PACKAGES
# comme ça on a une overview des dependances
